# %%
import pandas as pd
import numpy as np
import pickle

# %%
df = pd.read_csv('kurkMantoluMadonnaWords.csv',encoding='utf-8')

# %%
df.head()
# Out:
#    id   kelime       kok
# 0   1  mantolu  manto:lu
# 1   2  madonna   madonna
# 2   3  şimdiye  şimdi:ye
# 3   4    kadar     kadar
# 4   5  tesadüf   tesadüf

# %%
df_old = pd.read_csv('KOKBULTEST.txt',encoding='utf-8')

# %%
df_old.head()
# Out:
#       kelime         kok
# 0       açtı       aç:tı
# 1  dolaşmaya  dolaş:maya
# 2     kaygan      kaygan
# 3    dediğim    de:diğim
# 4      bütün       bütün

# %%
def is_valid(kelime,kok):
    ret = True
    try:
        if kelime.isupper() or kok.isupper():
            print "islower"
            ret = False
        elif not kelime.isalpha() and kelime.isalnum():
            print "kelime digits"
            ret = False
        elif not kok.replace(':','').isalpha() and kok.replace(':','').isalnum():
            print "kelime digits"
            ret = False
    except:
        ret = False
    return ret

# %%
sozluk = {}
def get_data(df,sozluk):
    for i in range(len(df)):
        kelime = df.kelime[i]
        kok = df.kok[i]
        if is_valid(kelime,kok):       
            if sozluk.has_key(kelime):
                if kok != sozluk[kelime]:
                    print u'Input : {} {} {} is already aded as {}'.format(i,kelime,kok,sozluk[kelime])
            else:
                sozluk[kelime] = kok
        else:
            print u'Input : {} {} {} not Valid '.format(i,kelime,kok)
            
    return sozluk

# %%
sozluk = get_data(df_old,sozluk)
len(sozluk)
# Out:
# 5571

# %%
sozluk = get_data(df,sozluk)
len(sozluk)
# Out:
# Input : 37 buna bu:na is already aded as buna
# Input : 53 adam ada:m is already aded as adam
# Input : 62 gün gü:n is already aded as gün
# Input : 83 kere ker:e is already aded as kere
# Input : 88 bunlar bu:nlar is already aded as bun:lar
# Input : 90 yaşıyorlar yaşa:yorlar is already aded as yaşa:ıyorlar
# Input : 103 bunu bu:nu is already aded as bun:u
# Input : 104 düşünürken düşün:ürken is already aded as düşünür:ken
# Input : 109 onların on:ların is already aded as onlar:ın
# Input : 113 bunun bu:nun is already aded as bun:un
# Input : 125 olacağını olacak:ını is already aded as ol:acağını
# Input : 149 olur olur is already aded as ol:ur
# Input : 160 dibinde dip:inde is already aded as dib:inde
# Input : 189 bilemiyorum bile:miyorum is already aded as bil:emiyorum
# Input : 190 bana ba:na is already aded as ban:a
# Input : 217 üzerinde üzerinde is already aded as üzeri:nde
# Input : 253 tarafından tarafından is already aded as taraf:ından
# Input : 255 sıra sır:a is already aded as sıra
# Input : 268 beni be:ni is already aded as ben:i
# Input : 272 hale hal:e is already aded as hale
# Input : 290 hızla hızla is already aded as hız:la
# Input : 314 işler iş:ler is already aded as işle:r
# Input : 322 onlardan on:lardan is already aded as onlar:dan
# Input : 337 içime iç:ime is already aded as içim:e
# Input : 343 istiyordum iste:yordum is already aded as iste:iyordum
# Input : 374 üstünde üst:ünde is already aded as üstün:de
# Input : 375 yer ye:r is already aded as yer
# Input : 384 görünüyorlardı görün:üyorlardı is already aded as gör:ünüyorlardı
# Input : 386 şeyi şe:yi is already aded as şey:i
# Input : 399 camın ca:mın is already aded as cam:ın
# Input : 406 adım ad:ım is already aded as adım
# Input : 410 açıldı aç:ıldı is already aded as açıl:dı
# Input : 418 nereye nereye is already aded as nere:ye
# Input : 426 beklemeden bekle:meden is already aded as bekleme:den
# Input : 427 yanında yanında is already aded as yan:ında
# Input : 443 seni se:ni is already aded as sen:i
# Input : 470 oldukça oldukça is already aded as ol:dukça
# Input : 473 biliyordum bile:yordum is already aded as bil:iyordum
# Input : 478 bulmasını bul:masını is already aded as bulma:sını
# Input : 487 mısın mı:sın is already aded as mısın
# Input : 493 verdim ver:dim is already aded as verdi:m
# Input : 517 kendinden kendinden is already aded as kendi:nden
# Input : 519 görünüyordu görün:üyordu is already aded as gör:ünüyordu
# Input : 520 demek demek is already aded as de:mek
# Input : 522 yardım yar:dım is already aded as yardım
# Input : 534 vardı var:dı is already aded as vard:ı
# Input : 550 kapının kap:ının is already aded as kapı:nın
# Input : 569 kısmını kısım:nı is already aded as kısım:ını
# Input : 574 ortada ortada is already aded as orta:da
# Input : 582 biri bir:i is already aded as biri
# Input : 636 yaşlı yaş:lı is already aded as yaşlı
# Input : 643 çıkarmadan çıkar:madan is already aded as çıkarma:dan
# Input : 646 üzeri üzer:i is already aded as üzeri
# Input : 651 birine bir:ine is already aded as biri:ne
# Input : 672 altına alt:ına is already aded as altın:a
# Input : 679 benziyordu benze:yordu is already aded as benze:iyordu
# Input : 681 birini bir:ini is already aded as biri:ni
# Input : 683 açmadan aç:madan is already aded as açma:dan
# Input : 685 göründü görün:dü is already aded as görü:ndü
# Input : 686 eliyle eliyle is already aded as el:iyle
# Input : 722 görünce gör:ünce is already aded as görü:nce
# Input : 737 eder et:er is already aded as eder
# Input : 738 gibiydi gib:iydi is already aded as gibi:ydi
# Input : 739 yazı yaz:ı is already aded as yazı
# Input : 742 musun mus:un is already aded as mu:sun
# Input : 765 aklına akıl:na is already aded as akıl:ına
# Input : 781 ona o:na is already aded as ona
# Input : 783 halimle hal:imle is already aded as halim:le
# Input : 809 gelen gelen is already aded as gele:n
# Input : 813 burada burada is already aded as bura:da
# Input : 818 yerinden yer:inden is already aded as yerinde:n
# Input : 823 elimi el:imi is already aded as elim:i
# Input : 831 anda a:nda is already aded as and:a
# Input : 883 onun o:nun is already aded as onun
# Input : 1013 şimdilik şimdilik is already aded as şimdi:lik
# Input : 1030 aslında aslında is already aded as asıl:ında
# Input : 1074 buradan buradan is already aded as bura:dan
# Input : 1076 nerede nerede is already aded as nere:de
# Input : 1086 oradan oradan is already aded as ora:dan
# Input : 1096 onu o:nu is already aded as onu
# Input : 1103 başkası başkası is already aded as başka:sı
# Input : 1108 nereden nereden is already aded as nere:den
# Input : 1113 senin se:nin is already aded as sen:in
# Input : 1128 ondan o:ndan is already aded as onda:n
# Input : 1135 orada orada is already aded as ora:da
# Input : 1148 bakan bak:an is already aded as bakan
# Input : 1156 sesle ses:le is already aded as sesle
# Input : 1167 üzerindeki üzer:indeki is already aded as üzeri:ndeki
# Input : 1185 hakkında hakkında is already aded as hak:kında
# Input : 1192 işe iş:e is already aded as işe
# Input : 1209 altından alt:ından is already aded as altın:dan
# Input : 1232 bakınca bak:ınca is already aded as bakın:ca
# Input : 1247 giderken git:erken is already aded as gider:ken
# Input : 1261 günlerce günlerce is already aded as gün:lerce
# Input : 1280 bağlı bağl:ı is already aded as bağlı
# Input : 1284 oraya oraya is already aded as ora:ya
# Input : 1309 bildiği bildik:i is already aded as bil:diği
# Input : 1313 bildiğini bildik:ini is already aded as bil:diğini
# Input : 1321 üzerinden üzer:inden is already aded as üzeri:nden
# Input : 1372 ağzından ağız:ndan is already aded as ağız:ından
# Input : 1373 kelime kel:ime is already aded as kelime
# Input : 1380 cebinde cep:inde is already aded as cebin:de
# Input : 1418 an a:n is already aded as an
# Input : 1424 ileride ileride is already aded as ileri:de
# Input : 1474 dolayısıyla dolayısıyla is already aded as dolayı:sıyla
# Input : 1495 zamanlar zaman:lar is already aded as zamanla:r
# Input : 1583 insanın insa:nın is already aded as insan:ın
# Input : 1585 farklı fark:lı is already aded as farklı
# Input : 1597 birbirine birbiri:ne is already aded as birbir:ine
# Input : 1628 yüzünden yüzünden is already aded as yüz:ünden
# Input : 1651 efendim efendim is already aded as efendi:m
# Input : 1658 onlara on:lara is already aded as onlar:a
# Input : 1665 çıktı çık:tı is already aded as çıktı
# Input : 1675 yerine yerine is already aded as yerin:e
# Input : 1678 insanı insa:nı is already aded as insan:ı
# Input : 1691 farkında fark:ında is already aded as farkında
# Input : 1701 görür gör:ür is already aded as görü:r
# Input : 1714 kalemi kale:mi is already aded as kalem:i
# Input : 1737 üzerine üzerine is already aded as üzeri:ne
# Input : 1742 içi iç:i is already aded as içi
# Input : 1761 şeklinde şekil:nde is already aded as şekli:nde
# Input : 1772 gözler göz:ler is already aded as gözle:r
# Input : 1781 burun bur:un is already aded as burun
# Input : 1784 doğrusu doğrusu is already aded as doğru:su
# Input : 1805 istiyor iste:yor is already aded as iste:iyor
# Input : 1809 ortaya orta:ya is already aded as ortay:a
# Input : 1818 acınacak acın:acak is already aded as acı:nacak
# Input : 1828 resim res:im is already aded as resim
# Input : 1836 içini iç:ini is already aded as için:i
# Input : 1854 şeye şe:ye is already aded as şey:e
# Input : 1886 kapı kap:ı is already aded as kapı
# Input : 1897 ele el:e is already aded as ele
# Input : 1902 elimden el:imden is already aded as elim:den
# Input : 1928 bundan bu:ndan is already aded as bun:dan
# Input : 1931 onunla on:unla is already aded as onun:la
# Input : 1964 yarına yar:ına is already aded as yarın:a
# Input : 2002 sonunda sonunda is already aded as son:unda
# Input : 2075 rahatsız rahat:sız is already aded as rahatsız
# Input : 2084 ister ister is already aded as iste:r
# Input : 2093 yana yana is already aded as yan:a
# Input : 2100 altında alt:ında is already aded as altın:da
# Input : 2137 ağzı ağız is already aded as ağız:ı
# Input : 2164 gözden göz:den is already aded as gözde:n
# Input : 2173 mısınız mı:sınız is already aded as mısınız
# Input : 2189 derdi der:di is already aded as dert:i
# Input : 2191 çıkmaya çık:maya is already aded as çıkma:ya
# Input : 2199 birinin bir:inin is already aded as biri:nin
# Input : 2206 girdi gir:di is already aded as girdi
# Input : 2218 cebinden cep:inden is already aded as cebin:den
# Input : 2226 alacak al:acak is already aded as alacak
# Input : 2232 vakti vakit is already aded as vakit:i
# Input : 2239 dinler din:ler is already aded as dinle:r
# Input : 2242 gider git:er is already aded as gider
# Input : 2258 onlar o:nlar is already aded as onlar
# Input : 2274 ederim et:erim is already aded as eder:im
# Input : 2285 yapmaya yap:maya is already aded as yapma:ya
# Input : 2304 oldu oldu is already aded as ol:du
# Input : 2310 aklımdan akıl:mdan is already aded as akıl:ımdan
# Input : 2332 der de:r is already aded as der
# Input : 2426 alaya ala:ya is already aded as alay:a
# Input : 2433 neydi ne:ydi is already aded as ney:di
# Input : 2476 andan a:ndan is already aded as an:dan
# Input : 2497 üstüne üstüne is already aded as üstün:e
# Input : 2499 onları on:ları is already aded as onlar:ı
# Input : 2501 bilemiyordu bile:miyordu is already aded as bil:emiyordu
# Input : 2528 diyen de:yen is already aded as de:iyen
# Input : 2550 olmaz olmaz is already aded as ol:maz
# Input : 2628 derken derken is already aded as derk:en
# Input : 2680 yüzden yüz:den is already aded as yüzde:n
# Input : 2731 görünmek görün:mek is already aded as gör:ünmek
# Input : 2750 aklı akıl is already aded as akıl:ı
# Input : 2836 bekler bek:ler is already aded as bekle:r
# Input : 2877 ağzını ağız:nı is already aded as ağız:ını
# Input : 2931 bunda bu:nda is already aded as bun:da
# Input : 2937 zamanla zaman:la is already aded as zamanla
# Input : 2964 sesini se:sini is already aded as ses:ini
# Input : 2966 ikinci ikinci is already aded as iki:nci
# Input : 2997 boyuna boyuna is already aded as boyun:a
# Input : 3008 birinden bir:inden is already aded as biri:nden
# Input : 3010 benden be:nden is already aded as bende:n
# Input : 3062 birden birden is already aded as bir:den
# Input : 3071 sesi se:si is already aded as ses:i
# Input : 3106 olacak olacak is already aded as ol:acak
# Input : 3109 bakarak bakarak is already aded as bak:arak
# Input : 3151 verdi ver:di is already aded as verdi
# Input : 3153 isterim iste:rim is already aded as isteri:m
# Input : 3154 bilir bilir is already aded as bili:r
# Input : 3181 benziyor benze:yor is already aded as benze:iyor
# Input : 3201 içinin iç:inin is already aded as için:in
# Input : 3216 altındaki alt:ındaki is already aded as altın:daki
# Input : 3230 söylüyordu söyle:yordu is already aded as söyle:üyordu
# Input : 3268 karar kar:ar is already aded as karar
# Input : 3284 ilerliyor ilerle:yor is already aded as ilerle:iyor
# Input : 3313 içinden iç:inden is already aded as içinde:n
# Input : 3423 içindeydi iç:indeydi is already aded as içinde:ydi
# Input : 3471 duyunca duy:unca is already aded as duyu:nca
# Input : 3483 olmazsa olmaz:sa is already aded as ol:mazsa
# Input : 3496 günü gü:nü is already aded as günü
# Input : 3509 iyiyim iy:iyim is already aded as iyi:yim
# Input : 3564 tavana tava:na is already aded as tavan:a
# Input : 3582 göze göz:e is already aded as göze
# Input : 3607 yeniden yeniden is already aded as yeni:den
# Input : 3618 ihtimali ihtimali is already aded as ihtimal:i
# Input : 3639 olurdu olur:du is already aded as ol:urdu
# Input : 3646 olursa olur:sa is already aded as ol:ursa
# Input : 3651 şeydi şe:ydi is already aded as şey:di
# Input : 3682 söylüyor söyle:yor is already aded as söyle:üyor
# Input : 3686 beyle be:yle is already aded as bey:le
# Input : 3688 canı ca:nı is already aded as can:ı
# Input : 3718 bende be:nde is already aded as bende
# Input : 3736 anlaşılmaz anlaşılmaz is already aded as anlaş:ılmaz
# Input : 3751 biliyorum bile:yorum is already aded as bil:iyorum
# Input : 3770 içindeki iç:indeki is already aded as içinde:ki
# kelime digits
# Input : 3791 20 20 not Valid
# kelime digits
# Input : 3793 1933 1933 not Valid
# Input : 3826 ölüme ölü:me is already aded as ölüm:e
# Input : 3851 musunuz mus:unuz is already aded as mu:sunuz
# Input : 3873 olamaz olamaz is already aded as ol:amaz
# Input : 3878 olabilir olabilir is already aded as ol:abilir
# Input : 3890 istiyorum iste:yorum is already aded as iste:iyorum
# Input : 3909 edemedi edeme:di is already aded as et:emedi
# Input : 3911 oku ok:u is already aded as oku
# Input : 3915 getirir getir:ir is already aded as getiri:r
# Input : 3954 boylu boylu is already aded as boy:lu
# Input : 3992 sonraki sonraki is already aded as sonra:ki
# Input : 4037 gelir gel:ir is already aded as gelir
# Input : 4039 yazmaya yaz:maya is already aded as yazma:ya
# Input : 4101 ismi isim is already aded as isim:i
# Input : 4102 ağızdan ağızdan is already aded as ağız:dan
# Input : 4131 kısmının kısım:nın is already aded as kısım:ının
# Input : 4161 oğlunu oğul:nu is already aded as oğul:unu
# Input : 4204 dediklerini dedik:lerini is already aded as de:diklerini
# Input : 4302 roma ro:ma is already aded as rom:a
# Input : 4346 korku kork:u is already aded as korku
# Input : 4348 yapmanın yap:manın is already aded as yapma:nın
# Input : 4384 giderek giderek is already aded as git:erek
# Input : 4421 sayesinde sayesinde is already aded as saye:sinde
# Input : 4458 sürmedi sür:medi is already aded as sürme:di
# Input : 4492 sapan sap:an is already aded as sapan
# Input : 4546 açılan aç:ılan is already aded as açıl:an
# Input : 4547 gelirdi gel:irdi is already aded as gelir:di
# Input : 4555 zamanında zamanında is already aded as zaman:ında
# Input : 4566 fikri fikri is already aded as fikir:i
# Input : 4607 yakında yakında is already aded as yakın:da
# Input : 4674 yaşamaya yaşa:maya is already aded as yaşama:ya
# Input : 4685 geçince geç:ince is already aded as geçin:ce
# Input : 4687 işten iş:ten is already aded as işte:n
# Input : 4697 aramaya ara:maya is already aded as arama:ya
# Input : 4723 in i:n is already aded as in
# Input : 4755 gününde gün:ünde is already aded as günü:nde
# Input : 4795 başlar baş:lar is already aded as başla:r
# Input : 4798 yapılmış yap:ılmış is already aded as yapıl:mış
# Input : 4885 boyun boy:un is already aded as boyun
# Input : 4911 öne ö:ne is already aded as ön:e
# Input : 4968 okurken oku:rken is already aded as okur:ken
# Input : 5031 diken dik:en is already aded as diken
# Input : 5034 görünen görün:en is already aded as gör:ünen
# Input : 5093 olabilirdi olabilir:di is already aded as ol:abilirdi
# Input : 5152 görünmez görünmez is already aded as gör:ünmez
# Input : 5187 yaşar yaşa:r is already aded as yaşar
# Input : 5223 kapılar kapı:lar is already aded as kapıl:ar
# Input : 5302 uzaktan uzaktan is already aded as uzak:tan
# Input : 5323 uzaklaştı uzaklaş:tı is already aded as uzak:laştı
# Input : 5338 çevirmeye çevir:meye is already aded as çevirme:ye
# Input : 5429 sallar sal:lar is already aded as salla:r
# Input : 5446 gelince gel:ince is already aded as gelin:ce
# Input : 5469 takıldı takıl:dı is already aded as tak:ıldı
# Input : 5493 kişi kiş:i is already aded as kişi
# Input : 5538 söyle sö:yle is already aded as söyle
# Input : 5597 biliyordu bile:yordu is already aded as bil:iyordu
# Input : 5658 bildiğim bildik:im is already aded as bil:diğim
# Input : 5692 olacaktı olacak:tı is already aded as ol:acaktı
# Input : 5738 anlıyor anla:yor is already aded as anla:ıyor
# Input : 5745 dışındaki dış:ındaki is already aded as dışı:ndaki
# Input : 5818 yukarıdan yukarıdan is already aded as yukarı:dan
# Input : 5890 sesler ses:ler is already aded as sesle:r
# Input : 5932 yerin yer:in is already aded as yerin
# Input : 5947 deniz de:niz is already aded as deniz
# Input : 6057 indi in:di is already aded as indi
# Input : 6110 bekliyor bekle:yor is already aded as bekle:iyor
# Input : 6147 sesiyle se:siyle is already aded as ses:iyle
# Input : 6149 başlıyor başla:yor is already aded as başla:ıyor
# Input : 6174 bulmaya bul:maya is already aded as bulma:ya
# Input : 6195 şarkı şark:ı is already aded as şarkı
# Input : 6223 selam sela:m is already aded as selam
# Input : 6244 içine iç:ine is already aded as için:e
# Input : 6336 düşünce düş:ünce is already aded as düşünce
# Input : 6364 dediğim dediği:m is already aded as de:diğim
# Input : 6371 resme resim is already aded as resim:e
# Input : 6373 biliyorsunuz bile:yorsunuz is already aded as bil:iyorsunuz
# Input : 6386 neyse neyse is already aded as ney:se
# Input : 6387 olabilirim olabilir:im is already aded as ol:abilirim
# Input : 6432 düşünceli düşüncel:i is already aded as düşünceli
# Input : 6433 kederli kederli is already aded as keder:li
# Input : 6438 günden gü:nden is already aded as gün:den
# Input : 6455 bozan boz:an is already aded as boza:n
# Input : 6469 arıyormuş ara:yormuş is already aded as ara:ıyormuş
# Input : 6552 birisinin biris:inin is already aded as birisi:nin
# Input : 6574 biliyor bile:yor is already aded as bil:iyor
# Input : 6683 edin et:in is already aded as edin
# Input : 6734 atıyordu ata:yordu is already aded as at:ıyordu
# Input : 6747 ederiz et:eriz is already aded as eder:iz
# Input : 6779 gelin gel:in is already aded as gelin
# Input : 6812 neredeyse neredeyse is already aded as nere:deyse
# Input : 6870 santim santi:m is already aded as santim
# Input : 6875 alın al:ın is already aded as alın
# Input : 6942 derdim der:dim is already aded as dert:im
# Input : 7028 eskiden eskiden is already aded as eski:den
# Input : 7048 görünmüyordu görün:müyordu is already aded as gör:ünmüyordu
# Input : 7112 olmazdı olmaz:dı is already aded as ol:mazdı
# Input : 7142 neye ne:ye is already aded as ney:e
# Input : 7159 gözle göz:le is already aded as gözle
# Input : 7219 fikriniz fikir:niz is already aded as fikir:iniz
# Input : 7239 gelirim gel:irim is already aded as gelir:im
# Input : 7252 otlar ot:lar is already aded as otla:r
# Input : 7331 söylüyorum söyle:yorum is already aded as söyle:üyorum
# Input : 7347 bence bence is already aded as ben:ce
# Input : 7360 tutulmuş tutul:muş is already aded as tut:ulmuş
# Input : 7414 kumlar kum:lar is already aded as kumla:r
# Input : 7462 ömrüm ömür:m is already aded as ömür:üm
# Input : 7463 boyunca boyunca is already aded as boyun:ca
# Input : 7565 bakın bak:ın is already aded as bakın
# Input : 7601 görünüyor görün:üyor is already aded as gör:ünüyor
# Input : 7714 sözler söz:ler is already aded as sözle:r
# Input : 7812 istiyorlar iste:yorlar is already aded as iste:iyorlar
# Input : 8003 gülümsüyordu gülümse:yordu is already aded as gülümse:üyordu
# Input : 8047 korkuyla kork:uyla is already aded as korku:yla
# Input : 8082 fikrini fikir:ni is already aded as fikir:ini
# Input : 8191 düşünün düş:ünün is already aded as düşün:ün
# Input : 8221 dışında dış:ında is already aded as dışı:nda
# Input : 8302 güne gü:ne is already aded as gün:e
# Input : 8329 havası hava:sı is already aded as havas:ı
# Input : 8337 birbirini birbiri:ni is already aded as birbir:ini
# Input : 8385 yapılan yapılan is already aded as yapıl:an
# Input : 8394 çıkar çık:ar is already aded as çıkar
# Input : 8400 dersin de:rsin is already aded as ders:in
# Input : 8430 sarılıp sar:ılıp is already aded as sarıl:ıp
# Input : 8450 üstünü üst:ünü is already aded as üstün:ü
# Input : 8544 ten te:n is already aded as ten
# Input : 8571 kıvrılıp kıvır:lıp is already aded as kıvrıl:ıp
# Input : 8577 öbürüne öbürü:ne is already aded as öbür:üne
# Input : 8654 sevgili sevgi:li is already aded as sevgili
# Input : 8667 deste des:te is already aded as deste
# Input : 8674 seslendi seslen:di is already aded as sesle:ndi
# Input : 8732 burnunun burun:nun is already aded as burun:unun
# Input : 8744 şüphesiz şüphesiz is already aded as şüphe:siz
# Input : 8843 istiyorsun iste:yorsun is already aded as iste:iyorsun
# Input : 8862 söylüyorsun söyle:yorsun is already aded as söyle:üyorsun
# Input : 8866 edeyim et:eyim is already aded as ede:yim
# Input : 8869 sende se:nde is already aded as sen:de
# Input : 8873 senden se:nden is already aded as sen:den
# Input : 8879 gittikçe gittikçe is already aded as git:tikçe
# Input : 8908 boşa boş:a is already aded as boşa
# Input : 8947 üstünden üst:ünden is already aded as üstün:den
# Input : 9053 fikrim fikir:m is already aded as fikir:im
# Input : 9144 yaşıyorlardı yaşa:yorlardı is already aded as yaşa:ıyorlardı
# Input : 9308 beşinci beşinci is already aded as beş:inci
# Input : 9429 telaşlı telaş:lı is already aded as telaşlı
# Input : 9449 karlı karl:ı is already aded as kar:lı
# Input : 9450 günde günde is already aded as gün:de
# Input : 9490 olacağına olacak:ına is already aded as ol:acağına
# Input : 9533 ederken et:erken is already aded as eder:ken
# Input : 9552 arıyor ara:yor is already aded as ara:ıyor
# Input : 9655 ikimizin ik:imizin is already aded as iki:mizin
# Input : 9683 izin iz:in is already aded as izin
# Input : 9698 görünmeye görün:meye is already aded as gör:ünmeye
# Input : 9799 verin ver:in is already aded as veri:n
# Input : 9819 içindekini iç:indekini is already aded as içinde:kini
# Input : 9825 olacaksa olacak:sa is already aded as ol:acaksa
# Input : 9833 gelirken gel:irken is already aded as gelir:ken
# Input : 9877 kafa kaf:a is already aded as kafa
# Input : 10038 koyar koy:ar is already aded as koyar
# Input : 10060 birisi biris:i is already aded as birisi
# Input : 10110 onsuz on:suz is already aded as ons:uz
# Input : 10243 başta başta is already aded as baş:ta
# Input : 10407 anında anında is already aded as anı:nda
# Input : 10519 yaşıyor yaşa:yor is already aded as yaşa:ıyor
# Input : 10585 sona so:na is already aded as son:a
# Input : 10615 oyun oy:un is already aded as oyun
# Input : 10700 sorun sor:un is already aded as sorun
# Input : 10723 diyelim de:yelim is already aded as diye:lim
# Input : 10914 duyulan duy:ulan is already aded as duyu:lan
# Input : 10989 birazdan birazdan is already aded as biraz:dan
# Input : 11053 açıldığı aç:ıldığı is already aded as açıl:dığı
# kelime digits
# Input : 11061 1940 1940 not Valid
# kelime digits
# Input : 11062 1941 1941 not Valid
# 14641

# %%
df_out = pd.DataFrame()
df_out['kelime'] = sozluk.keys()
df_out['kok'] = sozluk.values()

# %%
df_out.to_csv('kelime_kok.csv',encoding='utf-8',index=False)

# %%
fp = open('datafile.pkl','rb')
data = pickle.load(fp)
fp.close()

# %%
new_maxlen = max([len(x) for x in df_out.kelime ])
if data['maxlen'] < new_maxlen:
    data['maxlen'] = new_maxlen
    print 'New maxlen : ',new_maxlen    
    fp = open('datafile.pkl','wb')
    pickle.dump(data,fp)
    fp.close()    
    print 'datafile.pkl updated'
